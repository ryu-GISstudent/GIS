# %%
import geopandas as gpd
import pandas as pd

# %%
# データを変数に入れる
saitama_ku= gpd.read_file('saitama.geojson')

# %%
# とりあえずマップとしてアウトプット
saitama_ku.plot()
# Out:
# <Axes: >

# %%
# 最初の５列は？
saitama_ku.sample(6)
# Out:
#    N03_001  N03_002 N03_003 N03_004 N03_007  \
# 51     埼玉県      NaN     NaN     吉川市   11243
# 35     埼玉県      NaN     NaN     朝霞市   11227
# 33     埼玉県      NaN     NaN     戸田市   11224
# 57     埼玉県      NaN     入間郡     越生町   11327
# 65     埼玉県      NaN     比企郡   ときがわ町   11349
# 62     埼玉県      NaN     比企郡     吉見町   11347
#
#                                              geometry
# 51  POLYGON ((139.83634 35.93864, 139.83690 35.938...
# 35  POLYGON ((139.61703 35.83189, 139.61701 35.831...
# 33  POLYGON ((139.65778 35.83009, 139.65813 35.829...
# 57  POLYGON ((139.28273 35.99177, 139.28288 35.991...
# 65  POLYGON ((139.30101 36.03109, 139.30088 36.030...
# 62  POLYGON ((139.42629 36.07689, 139.42608 36.076...

# %%
# データの情報
saitama_ku.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   81 non-null     object
#  1   N03_002   0 non-null      float64
#  2   N03_003   38 non-null     object
#  3   N03_004   81 non-null     object
#  4   N03_007   81 non-null     object
#  5   geometry  81 non-null     geometry
# dtypes: float64(1), geometry(1), object(4)
# memory usage: 3.9+ KB

# %%
saitama_pop = pd.read_csv('pp.csv')

# %%
saitama_pop.head()
# Out:
#        KEY_CODE  HYOSYO CITYNAME   NAME  HTKSYORI  HTKSAKI  GASSAN   人口総数  \
# 0           NaN     NaN      NaN    NaN       NaN      NaN     NaN   人口総数
# 1  1.110100e+04     1.0  さいたま市西区    NaN       0.0      NaN     NaN  93499
# 2  1.110100e+08     2.0  さいたま市西区    宮前町       0.0      NaN     NaN   3327
# 3  1.110100e+08     3.0  さいたま市西区     三橋       0.0      NaN     NaN  13439
# 4  1.110100e+10     4.0  さいたま市西区  三橋五丁目       0.0      NaN     NaN   3643
#
#        男      女   世帯総数
# 0      男      女   世帯総数
# 1  45843  47656  38197
# 2   1665   1662   1360
# 3   6683   6756   5564
# 4   1806   1837   1550

# %%
saitama_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7062 entries, 0 to 7061
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KEY_CODE  7061 non-null   float64
#  1   HYOSYO    7061 non-null   float64
#  2   CITYNAME  7061 non-null   object
#  3   NAME      6989 non-null   object
#  4   HTKSYORI  7061 non-null   float64
#  5   HTKSAKI   0 non-null      float64
#  6   GASSAN    0 non-null      float64
#  7   人口総数      6951 non-null   object
#  8   男         6951 non-null   object
#  9   女         6938 non-null   object
#  10  世帯総数      6951 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 607.0+ KB

# %%
# rename
saitama_pop.rename(columns={'N03_003':'KEY_CODE'},inplace=True)

# %%
# check the new fieldname
saitama_pop
# Out:
#           KEY_CODE  HYOSYO CITYNAME      NAME  HTKSYORI  HTKSAKI  GASSAN  \
# 0              NaN     NaN      NaN       NaN       NaN      NaN     NaN
# 1     1.110100e+04     1.0  さいたま市西区       NaN       0.0      NaN     NaN
# 2     1.110100e+08     2.0  さいたま市西区       宮前町       0.0      NaN     NaN
# 3     1.110100e+08     3.0  さいたま市西区        三橋       0.0      NaN     NaN
# 4     1.110100e+10     4.0  さいたま市西区     三橋五丁目       0.0      NaN     NaN
# ...            ...     ...      ...       ...       ...      ...     ...
# 7057  1.146501e+08     3.0      松伏町     ゆめみ野東       0.0      NaN     NaN
# 7058  1.146501e+10     4.0      松伏町  ゆめみ野東一丁目       0.0      NaN     NaN
# 7059  1.146501e+10     4.0      松伏町  ゆめみ野東二丁目       0.0      NaN     NaN
# 7060  1.146501e+10     4.0      松伏町  ゆめみ野東三丁目       0.0      NaN     NaN
# 7061  1.146501e+10     4.0      松伏町  ゆめみ野東四丁目       0.0      NaN     NaN
#
#        人口総数      男      女   世帯総数
# 0      人口総数      男      女   世帯総数
# ...

# %%
saitama_pop['KEY_CODE'] = saitama_pop['KEY_CODE'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# c:\Users\ryu25\Desktop\GIS 俺の\GIS\week07課題\Week07.ipynb セル 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ryu25/Desktop/GIS%20%E4%BF%BA%E3%81%AE/GIS/week07%E8%AA%B2%E9%A1%8C/Week07.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> saitama_pop['KEY_CODE'] = saitama_pop['KEY_CODE'].astype(int)
#
# File c:\Users\ryu25\miniconda3\envs\gis\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# ...

# %%
# checkする
saitama1.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   81 non-null     object
#  1   N03_002   0 non-null      float64
#  2   KEY_CODE  38 non-null     object
#  3   N03_004   81 non-null     object
#  4   N03_007   81 non-null     object
#  5   geometry  81 non-null     geometry
# dtypes: float64(1), geometry(1), object(4)
# memory usage: 3.9+ KB

# %%
# ここでようやく merge コマンドで統合させて、新しい変数に入れる
saitama1= saitama1.merge(saitama1,on='KEY_CODE')

# %%
# check!
saitama1
# Out:
#      N03_001_x  N03_002_x KEY_CODE N03_004_x N03_007_x  \
# 0          埼玉県        NaN    さいたま市   さいたま市西区     11101
# 1          埼玉県        NaN    さいたま市   さいたま市西区     11101
# 2          埼玉県        NaN    さいたま市   さいたま市西区     11101
# 3          埼玉県        NaN    さいたま市   さいたま市西区     11101
# 4          埼玉県        NaN    さいたま市   さいたま市西区     11101
# ...        ...        ...      ...       ...       ...
# 2106       埼玉県        NaN     南埼玉郡       宮代町     11442
# 2107       埼玉県        NaN     北葛飾郡       杉戸町     11464
# 2108       埼玉県        NaN     北葛飾郡       杉戸町     11464
# 2109       埼玉県        NaN     北葛飾郡       松伏町     11465
# 2110       埼玉県        NaN     北葛飾郡       松伏町     11465
#
#                                              geometry_x N03_001_y  N03_002_y  \
# 0     POLYGON ((139.54776 35.93420, 139.54720 35.934...       埼玉県        NaN
# 1     POLYGON ((139.54776 35.93420, 139.54720 35.934...       埼玉県        NaN
# ...

# %%
saitama2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7096 entries, 0 to 7095
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KEY_CODE  7095 non-null   float64
#  1   HYOSYO    7095 non-null   float64
#  2   CITYNAME  7095 non-null   object
#  3   NAME      7023 non-null   object
#  4   HTKSYORI  7095 non-null   float64
#  5   HTKSAKI   0 non-null      float64
#  6   GASSAN    0 non-null      float64
#  7   人口総数      7096 non-null   object
#  8   男         7096 non-null   object
#  9   女         7096 non-null   object
#  10  世帯総数      7096 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 609.9+ KB

# %%
saitama2['人口総数'] = saitama2['人口総数'].astype (int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ryu25\Desktop\GIS 俺の\GIS\week07課題\Week07.ipynb セル 16 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ryu25/Desktop/GIS%20%E4%BF%BA%E3%81%AE/GIS/week07%E8%AA%B2%E9%A1%8C/Week07.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> saitama2['人口総数'] = saitama2['人口総数'].astype (int)
#
# File c:\Users\ryu25\miniconda3\envs\gis\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# ...

# %%
# check
saitama2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7096 entries, 0 to 7095
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KEY_CODE  7095 non-null   float64
#  1   HYOSYO    7095 non-null   float64
#  2   CITYNAME  7095 non-null   object
#  3   NAME      7023 non-null   object
#  4   HTKSYORI  7095 non-null   float64
#  5   HTKSAKI   0 non-null      float64
#  6   GASSAN    0 non-null      float64
#  7   人口総数      7096 non-null   object
#  8   男         7096 non-null   object
#  9   女         7096 non-null   object
#  10  世帯総数      7096 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 609.9+ KB

# %% [markdown]
# ### 4-3 Let's map!

# %%
saitama2.plot(column='人口総数',legend=True)
# Out:
# <Axes: >

# %%
saitama1.plot(figsize=(10,10),
                  column='人口総数',
                  legend=True)
# Out:
# <Axes: >

# %%
saitama1.plot(figsize=(10,10),
                  column='人口総数',
                  legend=True,
                  cmap='seismic')
# Out:
# <Axes: >
